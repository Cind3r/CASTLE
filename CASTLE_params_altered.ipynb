# %% [markdown]
# # **TODO:**
#
# - Alter the `NNmodel` classes to accept differnt model structures other than hidden layers
#     - add functionality for Sigmoid, remove Enable/Disable dropout, etc.
#     - adjust output to handle cases other than binary classification
#
# - Add more theoretical math models to explain the relationship
#
# - Update training methods to reward/punish complexity
#     - currently there are different methods for each, patch them into one

# %% [markdown]
# # C.A.S.T.L.E.
#
# #### Component Assembly Structure Tracking for Learning Emergence
#
# Castle is an assembly tracking neural network, which partitions weight tensors into `molecular blocks` and assigns `atomic codes` based on block statistics. The resulting `molecular lattice` encodes the network's structural motifs, enabling calculation of an assembly index that quantifies **modularity and reuse**. During training, the `loss function` incorporates a `complexity reward` or penalty derived from the assembly index, and gradients are modulated according to molecular reuse. If the assembly index exceeds a threshold, the architecture is evolved to favor more efficient or interpretable structures. This approach bridges neural network optimization with principles from assembly theory, promoting modularity, interpretability, and adaptive architectural evolution.
#
# ***
#
# ## Mathematical Framework for Atomic Molecules, Lattices, and Assembly Tracking in CASTLE
#
# ## 1. Atomic Molecule Definition and Construction
#
# ### 1.1 Weight Tensor Partitioning
#
# Given a weight tensor $W \in \mathbb{R}^{m \times n}$ from a neural network layer, we partition it into non-overlapping molecular blocks:
#
# $$W = \bigcup_{i=1}^{M} \bigcup_{j=1}^{N} W_{i,j}^{(k \times k)}$$
#
# where:
# - $M = \lfloor m/k \rfloor$: number of molecular blocks along rows
# - $N = \lfloor n/k \rfloor$: number of molecular blocks along columns
# - $k$: molecular block size (typically $k = 2$)
# - $W_{i,j}^{(k \times k)}$: molecular block at lattice position $(i,j)$
#
# ### 1.2 Atomic Weight Calculation
#
# For each molecular block $W_{i,j}^{(k \times k)}$, we compute its atomic weight:
#
# $$\omega_{i,j} = \frac{1}{k^2} \sum_{a=1}^{k} \sum_{b=1}^{k} W_{i,j}[a,b]$$
#
# where $\omega_{i,j}$ represents the average weight magnitude of the molecular block.
#
# ### 1.3 Atomic Symbol Assignment
#
# The atomic symbol $\sigma_{i,j}$ is assigned based on weight magnitude ranges:
#
# $$\sigma_{i,j} = \begin{cases}
# \text{Ze}^{\pm} & \text{if } 0.0 \leq |\omega_{i,j}| < 0.01 \\
# \text{Sm}^{\pm} & \text{if } 0.01 \leq |\omega_{i,j}| < 0.1 \\
# \text{Md}^{\pm} & \text{if } 0.1 \leq |\omega_{i,j}| < 0.5 \\
# \text{Lg}^{\pm} & \text{if } 0.5 \leq |\omega_{i,j}| < 1.0 \\
# \text{Xl}^{\pm} & \text{if } 1.0 \leq |\omega_{i,j}| < 2.0 \\
# \text{Xx}^{\pm} & \text{if } |\omega_{i,j}| \geq 2.0
# \end{cases}$$
#
# where the superscript $\pm$ indicates the sign of $\omega_{i,j}$.
#
# ### 1.4 Molecular Equivalence Relation
#
# Two molecules $\mathcal{M}_1$ and $\mathcal{M}_2$ are considered equivalent if:
#
# $$\mathcal{M}_1 \equiv \mathcal{M}_2 \iff \begin{cases}
# \sigma_1 = \sigma_2 & \text{(same atomic symbol)} \\
# |\omega_1 - \omega_2| < \epsilon & \text{(similar atomic weights)}
# \end{cases}$$
#
# where $\epsilon$ is the weight precision threshold (typically $\epsilon = 0.001$).
#
# ## 2. Molecular Lattice Structure
#
# ### 2.1 Lattice Definition
#
# A molecular lattice $\mathcal{L}$ is defined as:
#
# $$\mathcal{L} = \{(\mathcal{M}_{i,j}, \mathbf{p}_{i,j}) : 1 \leq i \leq M, 1 \leq j \leq N\}$$
#
# where:
# - $\mathcal{M}_{i,j}$: molecular block at lattice position $(i,j)$
# - $\mathbf{p}_{i,j} = (i,j)$: spatial position in the lattice
# - $M \times N$: lattice dimensions
#
# ### 2.2 Lattice Identification
#
# Each lattice is assigned a unique identifier:
#
# $$\text{ID}(\mathcal{L}) = \text{MD5}\left(\bigcup_{i=1}^{M} \bigcup_{j=1}^{N} \text{str}(\mathcal{M}_{i,j})\right)[:8]$$
#
# This ensures that lattices with identical molecular compositions receive the same ID.
#
# ### 2.3 Molecular Formula Representation
#
# The molecular formula of a lattice is:
#
# $$\mathcal{F}(\mathcal{L}) = \prod_{\sigma \in \Sigma} \sigma^{n_{\sigma}}$$
#
# where:
# - $\Sigma$: set of all atomic symbols in the lattice
# - $n_{\sigma}$: count of molecules with atomic symbol $\sigma$
#
# For example: $\mathcal{F}(\mathcal{L}) = \text{Ze}^3\text{Sm}^2\text{Md}^1$ indicates 3 zero-like, 2 small, and 1 medium molecule.
#
# ### 2.4 Lattice Similarity Metric
#
# The similarity between two lattices $\mathcal{L}_1$ and $\mathcal{L}_2$ is:
#
# $$\text{sim}(\mathcal{L}_1, \mathcal{L}_2) = \frac{|\mathcal{M}_1 \cap \mathcal{M}_2|}{|\mathcal{M}_1 \cup \mathcal{M}_2|}$$
#
# where $\mathcal{M}_1$ and $\mathcal{M}_2$ are the sets of unique molecules in each lattice.
#
# ## 3. Assembly Theory Framework
#
# ### 3.1 Assembly Pathway Definition
#
# An assembly pathway $\mathcal{P}(\mathcal{L})$ for lattice $\mathcal{L}$ is a sequence of assembly steps:
#
# $$\mathcal{P}(\mathcal{L}) = \{s_1, s_2, \ldots, s_k\}$$
#
# where each step $s_i$ is either:
# - $\text{reuse\_lattice}(\mathcal{L}_j)$: reuse molecules from existing lattice $\mathcal{L}_j$
# - $\text{atomic\_molecule}(\sigma)$: create new molecule with atomic symbol $\sigma$
#
# ### 3.2 Assembly Index Calculation
#
# The assembly index quantifies the complexity of constructing a lattice:
#
# $$A(\mathcal{L}) = \begin{cases}
# |\mathcal{U}(\mathcal{L})| & \text{if no reusable components} \\
# \sum_{i=1}^{k} c(s_i) & \text{if assembly pathway exists}
# \end{cases}$$
#
# where:
# - $\mathcal{U}(\mathcal{L})$: set of unique molecules in lattice $\mathcal{L}$
# - $c(s_i)$: cost of assembly step $s_i$ (typically $c(s_i) = 1$)
#
# ### 3.3 System Assembly Complexity
#
# The system-wide assembly complexity at epoch $t$ is:
#
# $$A_{\text{sys}}^{(t)} = \frac{1}{u_s} \sum_{s \in \mathcal{S}} e^{a_s} \cdot \frac{n_s - 1}{|\mathcal{S}|}$$
#
# where:
# - $\mathcal{S}$: set of all molecular lattices at epoch $t$
# - $u_s$: number of unique atomic symbols
# - $n_s$: frequency of atomic symbol $s$
# - $a_s$: assembly complexity of molecules with symbol $s$
# - $|\mathcal{S}|$: total number of molecular blocks
#
# ### 3.4 Molecular Reuse Tracking
#
# The reuse factor for molecule $\mathcal{M}$ is:
#
# $$\mathcal{R}(\mathcal{M}) = |\{\mathcal{L} \in \mathcal{L}_{\text{all}} : \mathcal{M} \in \mathcal{L}\}|$$
#
# where $\mathcal{L}_{\text{all}}$ is the set of all lattices discovered during training.
#
# ### 3.5 Assembly Pathway Optimization
#
# The optimal assembly pathway minimizes the total assembly cost:
#
# $$\mathcal{P}^*(\mathcal{L}) = \arg\min_{\mathcal{P}} \sum_{s_i \in \mathcal{P}} c(s_i)$$
#
# subject to the constraint that $\mathcal{P}$ can successfully construct $\mathcal{L}$.
#
# ## 4. Temporal Evolution and Tracking
#
# ### 4.1 Lattice Evolution Mapping
#
# The evolution of a layer's lattice structure is tracked as:
#
# $$\mathcal{L}_{\text{layer}}^{(t)} \to \mathcal{L}_{\text{layer}}^{(t+1)}$$
#
# where the transition probability is:
#
# $$P(\mathcal{L}_{\text{layer}}^{(t+1)} | \mathcal{L}_{\text{layer}}^{(t)}) = \exp\left(-\frac{d(\mathcal{L}_{\text{layer}}^{(t)}, \mathcal{L}_{\text{layer}}^{(t+1)})}{\tau}\right)$$
#
# with $d(\cdot, \cdot)$ being the lattice distance metric and $\tau$ the temperature parameter.
#
# ### 4.2 Molecular Discovery Rate
#
# The rate of new molecular discovery is:
#
# $$\frac{d|\mathcal{M}_{\text{library}}|}{dt} = \alpha \cdot (1 - \frac{|\mathcal{M}_{\text{library}}|}{|\mathcal{M}_{\text{max}}|})$$
#
# where $\alpha$ is the discovery rate parameter and $|\mathcal{M}_{\text{max}}|$ is the theoretical maximum number of unique molecules.
#
# ### 4.3 Assembly Complexity Evolution
#
# The evolution of system assembly complexity follows:
#
# $$\frac{dA_{\text{sys}}}{dt} = \beta \cdot (A_{\text{target}} - A_{\text{sys}}) - \gamma \cdot \mathcal{R}_{\text{avg}}$$
#
# where:
# - $A_{\text{target}}$: target assembly complexity
# - $\mathcal{R}_{\text{avg}}$: average molecular reuse factor
# - $\beta, \gamma$: evolution rate parameters
#
# ## 5. Gradient Modification Framework
#
# ### 5.1 Assembly-Aware Gradient Scaling
#
# The gradient for molecular block $W_{i,j}^{(k \times k)}$ is modified as:
#
# $$\nabla W_{i,j}^{(k \times k)} \leftarrow \nabla W_{i,j}^{(k \times k)} \cdot \mathcal{G}(\mathcal{M}_{i,j}, A(\mathcal{L}))$$
#
# where the gradient modifier is:
#
# $$\mathcal{G}(\mathcal{M}_{i,j}, A(\mathcal{L})) = \begin{cases}
# 0.8 & \text{if } \mathcal{R}(\mathcal{M}_{i,j}) > 1 \text{ (highly reused)} \\
# 1.2 & \text{if } \sigma_{i,j} = \text{Ze}^{\pm} \text{ (zero-like)} \\
# 0.9 & \text{if } A(\mathcal{L}) > \theta_{\text{complex}} \\
# 1.0 & \text{otherwise}
# \end{cases}$$
#
# ### 5.2 Complexity-Regularized Loss Function
#
# The total loss incorporates assembly complexity:
#
# $$\mathcal{L}_{\text{total}} = \mathcal{L}_{\text{base}} + \lambda \cdot \mathcal{R}_{\text{complexity}}(A_{\text{sys}})$$
#
# where the complexity regularizer is:
#
# $$\mathcal{R}_{\text{complexity}}(A_{\text{sys}}) = \begin{cases}
# -\alpha \cdot A_{\text{sys}} & \text{if } A_{\text{sys}} < A_{\text{optimal}} \\
# \beta \cdot (A_{\text{sys}} - A_{\text{optimal}})^2 & \text{if } A_{\text{sys}} > A_{\text{optimal}}
# \end{cases}$$
#
# ## 6. Architectural Evolution Criteria
#
# ### 6.1 Complexity-Based Architecture Suggestions
#
# Architecture modifications are suggested when:
#
# $$A_{\text{layer}} > \theta_{\text{split}} \Rightarrow \text{Suggest layer splitting}$$
# $$A_{\text{layer}} < \theta_{\text{merge}} \Rightarrow \text{Suggest layer merging}$$
#
# where $\theta_{\text{split}}$ and $\theta_{\text{merge}}$ are complexity thresholds.
#
# ### 6.2 Reuse-Based Architecture Optimization
#
# The architecture optimization objective is:
#
# $$\mathcal{O}_{\text{arch}} = \arg\min_{\text{arch}} \left[\mathcal{L}_{\text{accuracy}} + \lambda_1 \cdot A_{\text{sys}} - \lambda_2 \cdot \mathcal{R}_{\text{total}}\right]$$
#
# where $\mathcal{R}_{\text{total}}$ is the total molecular reuse across all layers.
#
# ## 7. Experimental Validation Framework
#
# ### 7.1 Complexity-Accuracy Relationship
#
# The relationship between assembly complexity and accuracy is modeled as:
#
# $$\mathcal{A}(A_{\text{sys}}) = \mathcal{A}_{\text{base}} + \gamma \cdot \left(1 - e^{-\beta \cdot A_{\text{sys}}}\right)$$
#
# or alternatively:
#
# $$\mathcal{A}(A_{\text{sys}}) = \mathcal{A}_{\text{max}} \cdot \exp\left(-\frac{(A_{\text{sys}} - \mu_{\text{opt}})^2}{2\sigma^2}\right) + \mathcal{A}_{\text{min}}$$
#
# ### 7.2 Statistical Validation Metrics
#
# The quality of the complexity-accuracy relationship is measured by:
#
# - **Coefficient of Determination**: $R^2 = 1 - \frac{\text{SS}_{\text{res}}}{\text{SS}_{\text{tot}}}$
# - **Root Mean Square Error**: $\text{RMSE} = \sqrt{\frac{1}{n}\sum_{i=1}^{n}(\mathcal{A}_i - \hat{\mathcal{A}}_i)^2}$
# - **Optimal Complexity**: $A_{\text{sys}}^* = \arg\max_{A_{\text{sys}}} \mathcal{A}(A_{\text{sys}})$
#
# This mathematical framework provides a rigorous foundation for understanding how atomic molecules are constructed, organized into lattices, and tracked through assembly theory principles in the CASTLE framework. The relationships capture both the static structural properties and the dynamic evolution of molecular patterns during neural network training.

# %% [markdown]
# ***

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, accuracy_score, confusion_matrix, classification_report
from sklearn.datasets import load_breast_cancer, load_iris, load_wine
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# self-made imports
from core.trainer import train_with_molecular_parameter_updates, train_basic, train_reward_complexity
from core.assembly import MolecularNeuralNet
from core.analyzer import validate_complexity_accuracy_relationship, analyze_complexity_accuracy_relationship
from visualize.lattice_builder import plot_pyvis_3d_lattice_interactive

# Suppress warnings for cleaner output
warnings.filterwarnings("ignore")
torch.manual_seed(42)
torch.cuda.manual_seed(42)
np.random.seed(42)

# %%
# Data Parameters
test_size = 0.2         # Proportion of the dataset to include in the test split (default for all functions is 0.2))
random_state = 42

# Data Loading Functions
def load_breast_cancer_data(test_size=0.2, random_state=42):
    # Load the breast cancer dataset
    data = load_breast_cancer()
    X, y = data.data, data.target
    # Split the dataset into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
    return X_train, X_test, y_train, y_test

def load_iris_data(test_size=0.2, random_state=42):
    # Load the iris dataset
    data = load_iris()
    X, y = data.data, data.target
    # Split the dataset into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
    return X_train, X_test, y_train, y_test

def load_wine_data(test_size=0.2, random_state=42):
    # Load the wine dataset
    data = load_wine()
    X, y = data.data, data.target
    # Split the dataset into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
    return X_train, X_test, y_train, y_test

def load_mnsit_data():
    # Load the MNIST dataset
    (x_train, y_train), (x_test, y_test) = mnist.load_data()
    y_train = to_categorical(y_train)
    y_test = to_categorical(y_test)
    x_train = x_train.astype('float32') / 255.
    x_test = x_test.astype('float32') / 255.
    x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
    x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
    return x_train, x_test, y_train, y_test

def to_one_hot(labels, num_classes):
    one_hot = torch.zeros(len(labels), num_classes)
    one_hot[range(len(labels)), labels] = 1
    return one_hot

# Output
try:
    X_train_cancer, X_test_cancer, y_train_cancer, y_test_cancer = load_breast_cancer_data(test_size, random_state)
    X_train_iris, X_test_iris, y_train_iris, y_test_iris = load_iris_data(test_size, random_state)
    X_train_wine, X_test_wine, y_train_wine, y_test_wine = load_wine_data(test_size, random_state)
    X_train_mnist, X_test_mnist, y_train_mnist, y_test_mnist = load_mnsit_data()
    print("Data loaded successfully.")
except Exception as e:
    print(f"An error occurred while loading the data: {e}")

# Print pd dataframe of dataset's shape, classes, and number of features
pd.DataFrame({
    "Dataset": ["Breast Cancer", "Iris", "Wine", "MNIST"],
    "Shape of Training Data": [X_train_cancer.shape, X_train_iris.shape, X_train_wine.shape, X_train_mnist.shape],
    "Number of Classes": [len(np.unique(y_train_cancer)), len(np.unique(y_train_iris)), len(np.unique(y_train_wine)), len(np.unique(y_train_mnist))],
    "Number of Features": [X_train_cancer.shape[1], X_train_iris.shape[1], X_train_wine.shape[1], X_train_mnist.shape[1]],
    "Classes": [np.unique(y_train_cancer), np.unique(y_train_iris), np.unique(y_train_wine), np.unique(y_train_mnist)]
}).set_index("Dataset").T.applymap(lambda x: x if isinstance(x, str) else str(x)).style.set_properties(**{'text-align': 'left'}).set_table_attributes('style="width: 100%; border-collapse: collapse;"').set_caption("Dataset Information").format(na_rep='N/A')
# Out:
# Data loaded successfully.
# <style type="text/css">
# #T_f2f71_row0_col0, #T_f2f71_row0_col1, #T_f2f71_row0_col2, #T_f2f71_row0_col3, #T_f2f71_row1_col0, #T_f2f71_row1_col1, #T_f2f71_row1_col2, #T_f2f71_row1_col3, #T_f2f71_row2_col0, #T_f2f71_row2_col1, #T_f2f71_row2_col2, #T_f2f71_row2_col3, #T_f2f71_row3_col0, #T_f2f71_row3_col1, #T_f2f71_row3_col2, #T_f2f71_row3_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_f2f71" style="width: 100%; border-collapse: collapse;">
#   <caption>Dataset Information</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Dataset</th>
#       <th id="T_f2f71_level0_col0" class="col_heading level0 col0" >Breast Cancer</th>
#       <th id="T_f2f71_level0_col1" class="col_heading level0 col1" >Iris</th>
#       <th id="T_f2f71_level0_col2" class="col_heading level0 col2" >Wine</th>
#       <th id="T_f2f71_level0_col3" class="col_heading level0 col3" >MNIST</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2f71_level0_row0" class="row_heading level0 row0" >Shape of Training Data</th>
#       <td id="T_f2f71_row0_col0" class="data row0 col0" >(455, 30)</td>
#       <td id="T_f2f71_row0_col1" class="data row0 col1" >(120, 4)</td>
#       <td id="T_f2f71_row0_col2" class="data row0 col2" >(142, 13)</td>
#       <td id="T_f2f71_row0_col3" class="data row0 col3" >(60000, 784)</td>
#     </tr>
#     <tr>
#       <th id="T_f2f71_level0_row1" class="row_heading level0 row1" >Number of Classes</th>
#       <td id="T_f2f71_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_f2f71_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_f2f71_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_f2f71_row1_col3" class="data row1 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_f2f71_level0_row2" class="row_heading level0 row2" >Number of Features</th>
#       <td id="T_f2f71_row2_col0" class="data row2 col0" >30</td>
#       <td id="T_f2f71_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_f2f71_row2_col2" class="data row2 col2" >13</td>
#       <td id="T_f2f71_row2_col3" class="data row2 col3" >784</td>
#     </tr>
#     <tr>
#       <th id="T_f2f71_level0_row3" class="row_heading level0 row3" >Classes</th>
#       <td id="T_f2f71_row3_col0" class="data row3 col0" >[0 1]</td>
#       <td id="T_f2f71_row3_col1" class="data row3 col1" >[0 1 2]</td>
#       <td id="T_f2f71_row3_col2" class="data row3 col2" >[0 1 2]</td>
#       <td id="T_f2f71_row3_col3" class="data row3 col3" >[0. 1.]</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ***
#
# ## Testing and Validation
#
# Let $\mathcal{A}(t)$ denote the model accuracy at time $t$, and $A_{\text{sys}}^{(t)}$ represent the system assembly complexity. The relationship between accuracy and complexity can be modeled as:
#
# $$\mathcal{A}(t) = \mathcal{A}_{\text{base}} + \gamma \cdot \left(1 - e^{-\beta \cdot A_{\text{sys}}^{(t)}}\right)$$
#
# where:
# - $\mathcal{A}_{\text{base}}$: base accuracy achievable with minimal complexity,
# - $\gamma$: maximum potential accuracy improvement from complexity,
# - $\beta$: rate parameter controlling how quickly complexity benefits manifest.
#
# This formulation captures three key properties:
# 1. As $A_{\text{sys}}^{(t)} \to 0$, $\mathcal{A}(t) \to \mathcal{A}_{\text{base}}$,
# 2. As $A_{\text{sys}}^{(t)} \to \infty$, $\mathcal{A}(t) \to \mathcal{A}_{\text{base}} + \gamma$,
# 3. The marginal benefit of additional complexity diminishes as complexity increases, reflecting the principle of diminishing returns.
#
# #### Alternative Formulation for Small Complexity Ranges
#
# For practical application with small ranges of complexity, a linear approximation may be suitable:
#
# $$\mathcal{A}(t) \approx \mathcal{A}_{\text{min}} + \delta \cdot A_{\text{sys}}^{(t)}$$
#
# where:
# - $\mathcal{A}_{\text{min}}$: minimum accuracy with zero complexity,
# - $\delta$: linear rate of accuracy improvement with complexity.
#
# See `core.analyzer` for code running analysis.
# >```python
# >def exponential_model(complexity, A_base, gamma, beta):
# >    """
# >    Exponential model for accuracy-complexity relationship:
# >    A(t) = A_base + γ * (1 - exp(-β * A_sys(t)))
# >    """
# >    return A_base + gamma * (1 - np.exp(-beta * complexity))
# >
# >def linear_model(complexity, A_min, delta):
# >    """
# >    Linear model for accuracy-complexity relationship:
# >    A(t) ≈ A_min + δ * A_sys(t)
# >    """
# >    return A_min + delta * complexity
# >```

# %%
# Example Usage of Training Functions
bc_model = MolecularNeuralNet(
    input_size=X_train_cancer.shape[1],
    hidden_sizes=[16, 8, 4],
    output_size=1,
    dropout=0.2
)


bc_model, bc_tracker, bc_losses, bc_accuracies, bc_complexities = train_with_molecular_parameter_updates(
    model=bc_model,
    X_train=X_train_cancer,
    y_train=y_train_cancer,
    X_test=X_test_cancer,
    y_test=y_test_cancer,
    epochs=50,
    lr=0.001,
    track_every=5,
    molecule_size=2,
    complexity_range=(3,8)    # Cap for beneficial complexity
)
# Out:
# Starting complexity-managed training (binary)...
# Epoch 0: 4 lattices, 32 unique molecules discovered
# Epoch 0: Loss=0.6948, Accuracy=0.6228, Complexity: 8.25
# Epoch 5: 4 lattices, 32 unique molecules discovered
# Epoch 10: 4 lattices, 33 unique molecules discovered
# Epoch 15: 4 lattices, 35 unique molecules discovered
# Epoch 20: 4 lattices, 35 unique molecules discovered
# Epoch 20: Loss=0.6879, Accuracy=0.6228, Complexity: 1.00
# Epoch 25: 4 lattices, 35 unique molecules discovered
# Epoch 30: 4 lattices, 36 unique molecules discovered
# Epoch 35: 4 lattices, 37 unique molecules discovered
# Epoch 40: 4 lattices, 37 unique molecules discovered
# Epoch 40: Loss=0.6757, Accuracy=0.6228, Complexity: 1.00
# Epoch 45: 4 lattices, 37 unique molecules discovered

# %%
# Example Usage of Analyzer Functions
bc_complexity_accuracy_df = validate_complexity_accuracy_relationship(
    tracker=bc_tracker,
    accuracies=bc_accuracies,
    dataset_name="Breast Cancer"
)

analyze_complexity_accuracy_relationship(
    accuracies=bc_accuracies, 
    complexities=bc_complexities, 
    dataset_name="Breast Cancer"
)
# Out:
# === Breast Cancer Complexity-Accuracy Relationship ===
# Exponential Model: A(t) = 0.3114 + 0.3114 * (1 - exp(-50.0000 * A_sys(t)))
#   R² = 0.0000, RMSE = 0.0000
# Linear Model: A(t) = 0.6228 + 0.0000 * A_sys(t)
#   R² = 0.0000, RMSE = 0.0000
# Best fitting model: Linear
# === Breast Cancer Complexity-Accuracy Analysis ===
# Linear model: accuracy = 0.6228 + -0.0000 * complexity
# Linear R²: 1.0000
#    complexity  accuracy  epoch
# 0        8.25  0.622807      0
# 1        0.75  0.622807      5
# 2        1.00  0.622807     10
# 3        1.50  0.622807     15
# 4        1.00  0.622807     20
# 5        1.00  0.622807     25
# 6        1.50  0.622807     30
# 7        1.25  0.622807     35
# 8        1.00  0.622807     40
# 9        1.00  0.622807     45

# %%
# Example with Scaled data
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train_cancer)
X_test_scaled = scaler.transform(X_test_cancer)

bc_model_scaled = MolecularNeuralNet(
    input_size=X_train_scaled.shape[1],
    hidden_sizes=[16, 8, 4],
    output_size=1,
    dropout=0.2
)

bc_model_scaled, bc_tracker_scaled, bc_losses_scaled, bc_accuracies_scaled, bc_complexities_scaled = train_with_molecular_parameter_updates(
    model=bc_model_scaled,
    X_train=X_train_scaled,
    y_train=y_train_cancer,
    X_test=X_test_scaled,
    y_test=y_test_cancer,
    epochs=50,
    lr=0.001,
    track_every=5,
    molecule_size=2,
    complexity_range=(3,8)    # Cap for beneficial complexity
)

# Report 
bc_complexity_accuracy_df_scaled = validate_complexity_accuracy_relationship(
    tracker=bc_tracker_scaled,
    accuracies=bc_accuracies_scaled,
    dataset_name="Breast Cancer Scaled"
)

analyze_complexity_accuracy_relationship(
    accuracies=bc_accuracies_scaled, 
    complexities=bc_complexities_scaled, 
    dataset_name="Breast Cancer Scaled"
)
# Out:
# Starting complexity-managed training (binary)...
# Epoch 0: 4 lattices, 28 unique molecules discovered
# Epoch 0: Loss=0.6598, Accuracy=0.6228, Complexity: 7.50
# Epoch 5: 4 lattices, 29 unique molecules discovered
# Epoch 10: 4 lattices, 30 unique molecules discovered
# Epoch 15: 4 lattices, 31 unique molecules discovered
# Epoch 20: 4 lattices, 31 unique molecules discovered
# Epoch 20: Loss=0.6588, Accuracy=0.6228, Complexity: 1.25
# Epoch 25: 4 lattices, 31 unique molecules discovered
# Epoch 30: 4 lattices, 31 unique molecules discovered
# Epoch 35: 4 lattices, 32 unique molecules discovered
# Epoch 40: 4 lattices, 32 unique molecules discovered
# Epoch 40: Loss=0.6539, Accuracy=0.6228, Complexity: 1.00
# Epoch 45: 4 lattices, 33 unique molecules discovered
# === Breast Cancer Scaled Complexity-Accuracy Relationship ===
# Exponential Model: A(t) = 0.3114 + 0.3114 * (1 - exp(-50.0000 * A_sys(t)))
#   R² = 0.0000, RMSE = 0.0000
# Linear Model: A(t) = 0.6228 + 0.0000 * A_sys(t)
#   R² = 0.0000, RMSE = 0.0000
# Best fitting model: Linear
# === Breast Cancer Scaled Complexity-Accuracy Analysis ===
# Linear model: accuracy = 0.6228 + -0.0000 * complexity
# Linear R²: 1.0000
#    complexity  accuracy  epoch
# 0        7.50  0.622807      0
# 1        1.25  0.622807      5
# 2        1.25  0.622807     10
# 3        1.25  0.622807     15
# 4        1.25  0.622807     20
# 5        1.25  0.622807     25
# 6        1.00  0.622807     30
# 7        1.25  0.622807     35
# 8        1.00  0.622807     40
# 9        1.25  0.622807     45

# %% [markdown]
# ***
# # Iris Data

# %%
iris_model = MolecularNeuralNet(
    input_size=X_train_iris.shape[1],
    hidden_sizes=[16, 8, 4],
    output_size=3,
    dropout=0.2
)

y_train_iris = to_one_hot(y_train_iris, num_classes=3)
y_test_iris = to_one_hot(y_test_iris, num_classes=3)

iris_model, iris_tracker, iris_losses, iris_accuracies, iris_complexities = train_with_molecular_parameter_updates(
    model=iris_model,
    X_train=X_train_iris,
    y_train=y_train_iris,
    X_test=X_test_iris,
    y_test=y_test_iris,
    epochs=50,
    lr=0.001,
    track_every=5,
    molecule_size=2,
    complexity_range=(3,8)    # Cap for beneficial complexity
)

# Iris complexity accuracy relationship
iris_complexity_accuracy_df = validate_complexity_accuracy_relationship(
    tracker=iris_tracker,
    accuracies=iris_accuracies,
    dataset_name="Iris"
)

analyze_complexity_accuracy_relationship(
    accuracies=iris_accuracies,
    complexities=iris_complexities,
    dataset_name="Iris"
)
# Out:
# Starting complexity-managed training (binary)...
# Epoch 0: 4 lattices, 27 unique molecules discovered
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 11
#       8 y_train_iris = (y_train_iris == 0).astype(int)
#       9 y_test_iris = (y_test_iris == 0).astype(int)
# ---> 11 iris_model, iris_tracker, iris_losses, iris_accuracies, iris_complexities = train_with_molecular_parameter_updates(
#      12     model=iris_model,
#      13     X_train=X_train_iris,
#      14     y_train=y_train_iris,
#      15     X_test=X_test_iris,
#      16     y_test=y_test_iris,
#      17     epochs=50,
#      18     lr=0.001,
#      19     track_every=5,
#      20     molecule_size=2,
#      21     complexity_range=(3,8)    # Cap for beneficial complexity
#      22 )
#      24 # Iris complexity accuracy relationship
#      25 iris_complexity_accuracy_df = validate_complexity_accuracy_relationship(
#      26     tracker=iris_tracker,
#      27     accuracies=iris_accuracies,
#      28     dataset_name="Iris"
#      29 )
#
# File c:\Users\jcing\OneDrive\Desktop\MADS\DATA 780\Project_CASTLE-repo\CASTLE\core\trainer.py:373, in train_with_molecular_parameter_updates(model, X_train, y_train, X_test, y_test, epochs, lr, track_every, molecule_size, complexity_range)
#     370 outputs = model(X_train_tensor)
#     372 if is_binary:
# --> 373     loss = criterion(outputs, y_train_tensor)
#     374 else:
#     375     # For multi-class, convert one-hot to class indices
#     376     targets = torch.argmax(y_train_tensor, dim=1)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\loss.py:821, in BCEWithLogitsLoss.forward(self, input, target)
#     820 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 821     return F.binary_cross_entropy_with_logits(
#     822         input,
#     823         target,
#     824         self.weight,
#     825         pos_weight=self.pos_weight,
#     826         reduction=self.reduction,
#     827     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\functional.py:3639, in binary_cross_entropy_with_logits(input, target, weight, size_average, reduce, reduction, pos_weight)
#    3636     reduction_enum = _Reduction.get_enum(reduction)
#    3638 if not (target.size() == input.size()):
# -> 3639     raise ValueError(
#    3640         f"Target size ({target.size()}) must be the same as input size ({input.size()})"
#    3641     )
#    3643 return torch.binary_cross_entropy_with_logits(
#    3644     input, target, weight, pos_weight, reduction_enum
#    3645 )
#
# ValueError: Target size (torch.Size([120, 1])) must be the same as input size (torch.Size([120, 3]))

# %%
# Example with Scaled data
scaler_iris = StandardScaler()

iris_X_train_scaled = scaler.fit_transform(X_train_iris)
iris_X_test_scaled = scaler.transform(X_test_iris)

# y_train_iris = (y_train_iris == 0).astype(int)
# y_test_iris = (y_test_iris == 0).astype(int)

iris_model_scaled = MolecularNeuralNet(
    input_size=iris_X_train_scaled.shape[1],
    hidden_sizes=[16, 8, 4],
    output_size=3,
    dropout=0.2
)

iris_model_scaled, iris_tracker_scaled, iris_losses_scaled, iris_accuracies_scaled, iris_complexities_scaled = train_with_molecular_parameter_updates(
    model=iris_model_scaled,
    X_train=iris_X_train_scaled,
    y_train=y_train_iris,
    X_test=iris_X_test_scaled,
    y_test=y_test_iris,
    epochs=50,
    lr=0.001,
    track_every=5,
    molecule_size=2,
    complexity_range=(3,8)    # Cap for beneficial complexity
)

# Report 
iris_complexity_accuracy_df_scaled = validate_complexity_accuracy_relationship(
    tracker=iris_tracker_scaled,
    accuracies=iris_accuracies_scaled,
    dataset_name="Iris Scaled"
)

analyze_complexity_accuracy_relationship(
    accuracies=iris_accuracies_scaled, 
    complexities=iris_complexities_scaled, 
    dataset_name="Iris Scaled"
)
# Out:
# Starting complexity-managed training (binary)...
# Epoch 0: 4 lattices, 21 unique molecules discovered
# Epoch 0: Loss=0.8074, Accuracy=0.3333, Complexity: 5.75
# Epoch 5: 4 lattices, 24 unique molecules discovered
# Epoch 10: 4 lattices, 26 unique molecules discovered
# Epoch 15: 4 lattices, 28 unique molecules discovered
# Epoch 20: 4 lattices, 28 unique molecules discovered
# Epoch 20: Loss=0.8034, Accuracy=0.3333, Complexity: 2.00
# Epoch 25: 4 lattices, 30 unique molecules discovered
# Epoch 30: 4 lattices, 32 unique molecules discovered
# Epoch 35: 4 lattices, 32 unique molecules discovered
# Epoch 40: 4 lattices, 34 unique molecules discovered
# Epoch 40: Loss=0.7972, Accuracy=0.3333, Complexity: 2.25
# Epoch 45: 4 lattices, 35 unique molecules discovered
# === Iris Scaled Complexity-Accuracy Relationship ===
# Exponential Model: A(t) = 0.1667 + 0.1667 * (1 - exp(-50.0000 * A_sys(t)))
#   R² = 0.0000, RMSE = 0.0000
# Linear Model: A(t) = 0.3333 + -0.0000 * A_sys(t)
#   R² = 0.0000, RMSE = 0.0000
# Best fitting model: Linear
# === Iris Scaled Complexity-Accuracy Analysis ===
# Linear model: accuracy = 0.3333 + -0.0000 * complexity
# Linear R²: 1.0000
#    complexity  accuracy  epoch
# 0        5.75  0.333333      0
# 1        1.50  0.333333      5
# 2        2.00  0.333333     10
# 3        2.25  0.333333     15
# 4        2.00  0.333333     20
# 5        2.50  0.333333     25
# 6        2.00  0.333333     30
# 7        1.75  0.333333     35
# 8        2.25  0.333333     40
# 9        2.50  0.333333     45

# %% [markdown]
# ***
# # MNIST

# %%
mnist_model = MolecularNeuralNet(
    input_size=X_train_mnist.shape[1],
    hidden_sizes=[128, 64, 32],
    output_size=10,
    dropout=0.2
)

mnist_model, mnist_tracker, mnist_losses, mnist_accuracies, mnist_complexities = train_with_molecular_parameter_updates(
    model=mnist_model,
    X_train=X_train_mnist,
    y_train=y_train_mnist,
    X_test=X_test_mnist,
    y_test=y_test_mnist,
    epochs=50,
    lr=0.001,
    track_every=5,
    molecule_size=2,
    complexity_range=(3,8)    # Cap for beneficial complexity
)

# MNIST complexity accuracy relationship
mnist_complexity_accuracy_df = validate_complexity_accuracy_relationship(
    tracker=mnist_tracker,
    accuracies=mnist_accuracies,
    dataset_name="MNIST"
)

analyze_complexity_accuracy_relationship(
    accuracies=mnist_accuracies,
    complexities=mnist_complexities,
    dataset_name="MNIST"
)
# Out:
# Starting complexity-managed training (multi-class)...
# Epoch 0: 4 lattices, 46 unique molecules discovered
# Epoch 0: Loss=2.3029, Accuracy=0.1589, Complexity: 12.50
# Epoch 5: 4 lattices, 48 unique molecules discovered
# Epoch 10: 4 lattices, 49 unique molecules discovered
# Epoch 15: 4 lattices, 49 unique molecules discovered
# Epoch 20: 4 lattices, 50 unique molecules discovered
# Epoch 20: Loss=2.0662, Accuracy=0.6194, Complexity: 1.50
# Epoch 25: 4 lattices, 51 unique molecules discovered
# Epoch 30: 4 lattices, 51 unique molecules discovered
# Epoch 35: 4 lattices, 53 unique molecules discovered
# Epoch 40: 4 lattices, 53 unique molecules discovered
# Epoch 40: Loss=1.8146, Accuracy=0.7799, Complexity: 1.75
# Epoch 45: 4 lattices, 54 unique molecules discovered
# === MNIST Complexity-Accuracy Relationship ===
# Exponential Model: A(t) = 0.2867 + 0.2867 * (1 - exp(-50.0000 * A_sys(t)))
#   R² = 0.0000, RMSE = 0.2093
# Linear Model: A(t) = 0.6960 + -0.0430 * A_sys(t)
#   R² = 0.4446, RMSE = 0.1560
# Best fitting model: Linear
# === MNIST Complexity-Accuracy Analysis ===
# Linear model: accuracy = 0.6960 + -0.0430 * complexity
# Linear R²: 0.4446
# Quadratic model better explains the relationship (R²=0.4446)
# Estimated optimal complexity: 68.01
#    complexity  accuracy  epoch
# 0       12.50    0.1589      0
# 1        2.25    0.3234      5
# 2        2.00    0.3810     10
# 3        1.00    0.5162     15
# 4        1.50    0.6194     20
# 5        2.00    0.6637     25
# 6        1.50    0.7304     30
# 7        2.50    0.7642     35
# 8        1.75    0.7799     40
# 9        1.50    0.7963     45

# %%
# Example with Scaled data
scaler = StandardScaler()

mnist_X_train_scaled = scaler.fit_transform(X_train_mnist)
mnist_X_test_scaled = scaler.transform(X_test_mnist)

mnist_model_scaled = MolecularNeuralNet(
    input_size=mnist_X_train_scaled.shape[1],
    hidden_sizes=[128, 64, 32],
    output_size=10,
    dropout=0.2
)

mnist_model_scaled, mnist_tracker_scaled, mnist_losses_scaled, mnist_accuracies_scaled, mnist_complexities_scaled = train_with_molecular_parameter_updates(
    model=mnist_model_scaled,
    X_train=mnist_X_train_scaled,
    y_train=y_train_mnist,
    X_test=mnist_X_test_scaled,
    y_test=y_test_mnist,
    epochs=50,
    lr=0.001,
    track_every=5,
    molecule_size=2,
    complexity_range=(3,8)    # Cap for beneficial complexity
)

# Report
mnist_complexity_accuracy_df_scaled = validate_complexity_accuracy_relationship(
    tracker=mnist_tracker_scaled,
    accuracies=mnist_accuracies_scaled,
    dataset_name="MNIST Scaled"
)

analyze_complexity_accuracy_relationship(
    accuracies=mnist_accuracies_scaled, 
    complexities=mnist_complexities_scaled, 
    dataset_name="MNIST Scaled"
)
# Out:
# Starting complexity-managed training (multi-class)...
# Epoch 0: 4 lattices, 44 unique molecules discovered
# Epoch 0: Loss=2.3152, Accuracy=0.1131, Complexity: 12.00
# Epoch 5: 4 lattices, 44 unique molecules discovered
# Epoch 10: 4 lattices, 45 unique molecules discovered
# Epoch 15: 4 lattices, 46 unique molecules discovered
# Epoch 20: 4 lattices, 46 unique molecules discovered
# Epoch 20: Loss=1.9503, Accuracy=0.6334, Complexity: 1.75
# Epoch 25: 4 lattices, 48 unique molecules discovered
# Epoch 30: 4 lattices, 48 unique molecules discovered
# Epoch 35: 4 lattices, 49 unique molecules discovered
# Epoch 40: 4 lattices, 50 unique molecules discovered
# Epoch 40: Loss=1.7339, Accuracy=0.8120, Complexity: 2.00
# Epoch 45: 4 lattices, 51 unique molecules discovered
# === MNIST Scaled Complexity-Accuracy Relationship ===
# Exponential Model: A(t) = 0.3024 + 0.3024 * (1 - exp(-50.0000 * A_sys(t)))
#   R² = -0.0000, RMSE = 0.2140
# Linear Model: A(t) = 0.7422 + -0.0519 * A_sys(t)
#   R² = 0.5738, RMSE = 0.1397
# Best fitting model: Linear
# === MNIST Scaled Complexity-Accuracy Analysis ===
# Linear model: accuracy = 0.7422 + -0.0519 * complexity
# Linear R²: 0.5738
# Quadratic model better explains the relationship (R²=0.5915)
# Estimated optimal complexity: 4.62
#    complexity  accuracy  epoch
# 0       12.00    0.1131      0
# 1        1.50    0.3665      5
# 2        1.50    0.5160     10
# 3        1.75    0.5768     15
# 4        1.75    0.6334     20
# 5        1.25    0.6847     25
# 6        1.75    0.7293     30
# 7        1.75    0.7719     35
# 8        2.00    0.8120     40
# 9        1.25    0.8437     45

# %% [markdown]
# ***
# # Wine

# %%
# Wine dataset
wine_model = MolecularNeuralNet(
    input_size=X_train_wine.shape[1],
    hidden_sizes=[16, 8, 4],
    output_size=3,
    dropout=0.2
)

y_train_wine = to_one_hot(y_train_wine, num_classes=3)
y_test_wine = to_one_hot(y_test_wine, num_classes=3)

wine_model, wine_tracker, wine_losses, wine_accuracies, wine_complexities = train_with_molecular_parameter_updates(
    model=wine_model,
    X_train=X_train_wine,
    y_train=y_train_wine,
    X_test=X_test_wine,
    y_test=y_test_wine,
    epochs=50,
    lr=0.001,
    track_every=5,
    molecule_size=2,
    complexity_range=(3,8)    # Cap for beneficial complexity
)

# Wine complexity accuracy relationship
wine_complexity_accuracy_df = validate_complexity_accuracy_relationship(
    tracker=wine_tracker,
    accuracies=wine_accuracies,
    dataset_name="Wine"
)

analyze_complexity_accuracy_relationship(
    accuracies=wine_accuracies,
    complexities=wine_complexities,
    dataset_name="Wine"
)
# Out:
# Starting complexity-managed training (binary)...
# Epoch 0: 4 lattices, 28 unique molecules discovered
# Epoch 0: Loss=0.4627, Accuracy=0.3889, Complexity: 7.50
# Epoch 5: 4 lattices, 30 unique molecules discovered
# Epoch 10: 4 lattices, 32 unique molecules discovered
# Epoch 15: 4 lattices, 33 unique molecules discovered
# Epoch 20: 4 lattices, 33 unique molecules discovered
# Epoch 20: Loss=0.3912, Accuracy=0.3889, Complexity: 1.50
# Epoch 25: 4 lattices, 33 unique molecules discovered
# Epoch 30: 4 lattices, 34 unique molecules discovered
# Epoch 35: 4 lattices, 34 unique molecules discovered
# Epoch 40: 4 lattices, 34 unique molecules discovered
# Epoch 40: Loss=0.3771, Accuracy=0.3889, Complexity: 0.75
# Epoch 45: 4 lattices, 34 unique molecules discovered
# === Wine Complexity-Accuracy Relationship ===
# Exponential Model: A(t) = 0.1944 + 0.1944 * (1 - exp(-50.0000 * A_sys(t)))
#   R² = 0.0000, RMSE = 0.0000
# Linear Model: A(t) = 0.3889 + -0.0000 * A_sys(t)
#   R² = 0.0000, RMSE = 0.0000
# Best fitting model: Linear
# === Wine Complexity-Accuracy Analysis ===
# Linear model: accuracy = 0.3889 + -0.0000 * complexity
# Linear R²: 1.0000
#    complexity  accuracy  epoch
# 0        7.50  0.388889      0
# 1        1.75  0.388889      5
# 2        2.25  0.388889     10
# 3        1.00  0.388889     15
# 4        1.50  0.388889     20
# 5        1.75  0.388889     25
# 6        1.25  0.388889     30
# 7        1.00  0.388889     35
# 8        0.75  0.388889     40
# 9        1.00  0.388889     45

# %%
# Wine Scaled data
scaler_wine = StandardScaler()
wine_X_train_scaled = scaler_wine.fit_transform(X_train_wine)
wine_X_test_scaled = scaler_wine.transform(X_test_wine)

wine_model_scaled = MolecularNeuralNet(
    input_size=wine_X_train_scaled.shape[1],
    hidden_sizes=[16, 8, 4],
    output_size=3,
    dropout=0.2
)
wine_model_scaled, wine_tracker_scaled, wine_losses_scaled, wine_accuracies_scaled, wine_complexities_scaled = train_with_molecular_parameter_updates(
    model=wine_model_scaled,
    X_train=wine_X_train_scaled,
    y_train=y_train_wine,
    X_test=wine_X_test_scaled,
    y_test=y_test_wine,
    epochs=50,
    lr=0.001,
    track_every=5,
    molecule_size=2,
    complexity_range=(3,8)    # Cap for beneficial complexity
)

# Report
wine_complexity_accuracy_df_scaled = validate_complexity_accuracy_relationship(
    tracker=wine_tracker_scaled,
    accuracies=wine_accuracies_scaled,
    dataset_name="Wine Scaled"
)

analyze_complexity_accuracy_relationship(
    accuracies=wine_accuracies_scaled,
    complexities=wine_complexities_scaled,
    dataset_name="Wine Scaled"
)
# Out:
# Starting complexity-managed training (binary)...
# Epoch 0: 4 lattices, 28 unique molecules discovered
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 12
#       4 wine_X_test_scaled = scaler_wine.transform(X_test_wine)
#       6 wine_model_scaled = MolecularNeuralNet(
#       7     input_size=wine_X_train_scaled.shape[1],
#       8     hidden_sizes=[16, 8, 4],
#       9     output_size=3,
#      10     dropout=0.2
#      11 )
# ---> 12 wine_model_scaled, wine_tracker_scaled, wine_losses_scaled, wine_accuracies_scaled, wine_complexities_scaled = train_with_molecular_parameter_updates(
#      13     model=wine_model_scaled,
#      14     X_train=wine_X_train_scaled,
#      15     y_train=y_train_wine,
#      16     X_test=wine_X_test_scaled,
#      17     y_test=y_test_wine,
#      18     epochs=50,
#      19     lr=0.001,
#      20     track_every=5,
#      21     molecule_size=2,
#      22     complexity_range=(3,8)    # Cap for beneficial complexity
#      23 )
#      25 # Report
#      26 wine_complexity_accuracy_df_scaled = validate_complexity_accuracy_relationship(
#      27     tracker=wine_tracker_scaled,
#      28     accuracies=wine_accuracies_scaled,
#      29     dataset_name="Wine Scaled"
#      30 )
#
# File c:\Users\jcing\OneDrive\Desktop\MADS\DATA 780\Project_CASTLE-repo\CASTLE\core\trainer.py:373, in train_with_molecular_parameter_updates(model, X_train, y_train, X_test, y_test, epochs, lr, track_every, molecule_size, complexity_range)
#     370 outputs = model(X_train_tensor)
#     372 if is_binary:
# --> 373     loss = criterion(outputs, y_train_tensor)
#     374 else:
#     375     # For multi-class, convert one-hot to class indices
#     376     targets = torch.argmax(y_train_tensor, dim=1)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\loss.py:821, in BCEWithLogitsLoss.forward(self, input, target)
#     820 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 821     return F.binary_cross_entropy_with_logits(
#     822         input,
#     823         target,
#     824         self.weight,
#     825         pos_weight=self.pos_weight,
#     826         reduction=self.reduction,
#     827     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\functional.py:3639, in binary_cross_entropy_with_logits(input, target, weight, size_average, reduce, reduction, pos_weight)
#    3636     reduction_enum = _Reduction.get_enum(reduction)
#    3638 if not (target.size() == input.size()):
# -> 3639     raise ValueError(
#    3640         f"Target size ({target.size()}) must be the same as input size ({input.size()})"
#    3641     )
#    3643 return torch.binary_cross_entropy_with_logits(
#    3644     input, target, weight, pos_weight, reduction_enum
#    3645 )
#
# ValueError: Target size (torch.Size([142, 1])) must be the same as input size (torch.Size([142, 3]))
